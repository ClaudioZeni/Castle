# %% [markdown]
# # BEFORE YOU START
#
# * Make sure you have the latest julia, julip, ace, installed
# * Change the JULIA_UTILS_PATH in ace_interface.py to point to your castle folder
# * Copy the delta_silicon.xyz data to "../data/Si_2018/delta_silicon.xyz"

# %%
from ase.io import read
import numpy as np
import sys
from matplotlib import pyplot as plt

import joblib
import pickle
sys.path.insert(0,"../")
from castle import train_ensamble_linear_model, ASEMLCalculator, AceGlobalRepresentation, train_linear_model
from castle import get_forces_and_energies, get_virials, get_nat, dump, load, print_score

def split_dataset(N, training_percentage, seed=20):
    np.random.seed(seed)
    ids = list(range(N))
    np.random.shuffle(ids)
    return ids[:int(training_percentage*N)], ids[int(training_percentage*N):]

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load structures

# %%
# Load xyz data
input_file =  "/home/claudio/postdoc/integrated_potentials/data/Si_2018/delta_silicon.xyz"
frames_ = read(input_file, index = ':')
    
# Wrap positions so rascal does not complain
for ff in frames_:
    ff.wrap(eps=1e-11)
energy_name = 'dft_energy'
force_name = 'dft_force'
virial_name = 'dft_virial'

# %%
tags = set()
for ff in frames_:
    tags.add(ff.info['config_type'])
print(tags)
# Out:
# {'isolated_atom', 'sh', 'surface_111', 'hcp', 'surface_001', 'surface_111_3x3_das', 'vacancy', '111adatom', 'screw_disloc', 'crack_110_1-10', 'interstitial', 'hex_diamond', 'surface_111_pandey', 'bc8', 'bcc', 'bt', 'crack_111_1-10', 'surface_110', 'sp', 'divacancy', 'amorph', 'decohesion', 'liq', 'dia', 'fcc', 'sp2', 'st12'}

# %%
# build a potential for diamond phase only
frames = []
for ff in frames_:
    if ff.info['config_type'] in ['amorph', 'bt', 'dia', 'liq', 'fcc', 'bcc', 'hcp', 'hex_diamond']:
        try:
            len(ff.info['dft_virial'])
            frames.append(ff)
        except KeyError:
            pass

# %% [markdown]
# # Build a model

# %% [markdown]
# Compute representation

# %%
# Create training and validation set
tr_ind, val_ind = split_dataset(len(frames), 0.8)
tr_frames = [frames[s] for s in tr_ind]
val_frames = [frames[s] for s in val_ind]
e_t, f_t = get_forces_and_energies(tr_frames, energy_name = energy_name, force_name = force_name)
e_val, f_val = get_forces_and_energies(val_frames, energy_name = energy_name, force_name = force_name)
s_val = get_virials(val_frames, virial_name)
nat_val = get_nat(val_frames)

N = 8               # Body order
maxdeg = 10         # Number of basis (?)
rcut = 5.0          # Radial Cutoff
r0 = 1.0            # Lowest radius for basis
reg = 1e-8          # Ridge regularizer
species = 14        # Atomic number of species


representation = AceGlobalRepresentation(N, maxdeg, rcut, species, r0, reg, 
                                         energy_name=energy_name, force_name=force_name, virial_name=virial_name)

# %%
#  compute features
features = representation.transform(frames)
#  save them
# dump('./features.xz', features)

# %% [markdown]
# Train a linear model

# %%
# load the features
# features = load('./features.xz')
noise = 1e-6
# get the subset of features for training
tr_features = features.get_subset(tr_ind)
# train the model
model = train_linear_model(tr_features, noise, e_t, f_t)

# %%
# evaluate its performances
val_features = features.get_subset(val_ind)
ep = model.predict(val_features)
fp = model.predict_forces(val_features)


print_score(ep/nat_val, e_val/nat_val)
print_score(fp.flatten(), f_val.flatten())
# print_score(vp.flatten(), s_val.flatten())

plt.scatter(e_val/nat_val, ep/nat_val)
plt.plot(e_val/nat_val, e_val/nat_val, 'k--')
plt.xlabel("True Energy [eV/atom]")
plt.ylabel("Predicted Energy [eV/atom]")
plt.show()

plt.scatter(f_val, fp)
plt.plot(f_val, f_val, 'k--')
plt.xlabel("True Force [eV/$\AA$]")
plt.ylabel("Predicted Force [eV/$\AA$]")
plt.show()
# Out:
# MAE=0.04 RMSE=0.07 SUP=0.36 R2=0.91
# MAE=0.26 RMSE=0.41 SUP=3.95 R2=0.45

# %% [markdown]
# ## train an ensemble of linear models

# %%
n_clusters = 5
n_neighbours = 10

# %%
# features = load('./features.xz')

# %%
noise = 1e-8
# get the subset of features for training
tr_features = features.get_subset(tr_ind)
# train the model
model =  train_ensamble_linear_model(tr_features, noise, e_t, f_t,
                        n_neighbours=n_neighbours, 
                         hyper=n_clusters, clustering='e_gmm')

# %%
# evaluate its performances
val_features = features.get_subset(val_ind)
ep = model.predict(val_features)
fp = model.predict_forces(val_features)
# vp = model.predict_stress(val_features)

print_score(ep/nat_val, e_val/nat_val)
print_score(fp.flatten(), f_val.flatten())
# print_score(vp.flatten(), s_val.flatten())

plt.scatter(e_val/nat_val, ep/nat_val)
plt.plot(e_val/nat_val, e_val/nat_val, 'k--')
plt.xlabel("True Energy [eV/atom]")
plt.ylabel("Predicted Energy [eV/atom]")
plt.show()

plt.scatter(f_val, fp)
plt.plot(f_val, f_val, 'k--')
plt.xlabel("True Force [eV/$\AA$]")
plt.ylabel("Predicted Force [eV/$\AA$]")
plt.show()
# Out:
# MAE=0.04 RMSE=0.09 SUP=0.29 R2=0.85
# MAE=0.18 RMSE=0.32 SUP=2.43 R2=0.61

# %%
# save the model
dump('./model.xz',model)
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-99-483930c3e31c> in <module>
#       1 # save the model
# ----> 2 dump('./model.xz',model)
#
# ~/postdoc/Castle/notebooks/../castle/utils.py in dump(fn, obj, compress, protocol)
#       6
#       7 def dump(fn, obj, compress=3, protocol=pickle.HIGHEST_PROTOCOL):
# ----> 8     joblib.dump(obj, fn, protocol=protocol, compress=compress)
#       9
#      10
#
# ~/.local/lib/python3.8/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     475         with _write_fileobject(filename, compress=(compress_method,
#     476                                                    compress_level)) as f:
# --> 477             NumpyPickler(f, protocol=protocol).dump(value)
#     478     elif is_filename:
#     479         with open(filename, 'wb') as f:
#
# /usr/lib/python3.8/pickle.py in dump(self, obj)
#     485         if self.proto >= 4:
#     486             self.framer.start_framing()
# --> 487         self.save(obj)
#     488         self.write(STOP)
#     489         self.framer.end_framing()
#
# ~/.local/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /usr/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# /usr/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~/.local/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /usr/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /usr/lib/python3.8/pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# /usr/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~/.local/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /usr/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /usr/lib/python3.8/pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# /usr/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~/.local/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /usr/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# /usr/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~/.local/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /usr/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /usr/lib/python3.8/pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# /usr/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~/.local/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /usr/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# /usr/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     685                     "args[0] from __newobj__ args has the wrong class")
#     686             args = args[1:]
# --> 687             save(cls)
#     688             save(args)
#     689             write(NEWOBJ)
#
# ~/.local/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /usr/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /usr/lib/python3.8/pickle.py in save_type(self, obj)
#    1126         elif obj is type(...):
#    1127             return self.save_reduce(type, (...,), obj=obj)
# -> 1128         return self.save_global(obj)
#    1129
#    1130     dispatch[FunctionType] = save_global
#
# /usr/lib/python3.8/pickle.py in save_global(self, obj, name)
#    1073         else:
#    1074             if obj2 is not obj:
# -> 1075                 raise PicklingError(
#    1076                     "Can't pickle %r: it's not the same object as %s.%s" %
#    1077                     (obj, module_name, name))
#
# PicklingError: Can't pickle <class 'castle.representation.AceGlobalRepresentation'>: it's not the same object as castle.representation.AceGlobalRepresentation

# %% [markdown]
# # use the model for cell optimization

# %%
from ase.lattice.cubic import FaceCenteredCubic, Diamond
from scipy.optimize import leastsq, minimize
from ase.build import bulk
from ase.optimize import LBFGS
from ase.optimize import FIRE
from ase.optimize import MDMin
from ase.md.langevin import Langevin
from ase import constraints
from ase.constraints import StrainFilter

# %%
model = load('./model.xz')

# %%
calc = ASEMLCalculator(model, model.representation)

# %%
frames[0].positions.shape
# Out:
# (2, 3)

# %%
features.dX_dr[:2].shape
# Out:
# (2, 3, 210)

# %%
np.einsum('mcd, mf -> cfd', features.dX_dr[:2], frames[0].positions)[:, :, 0]
# Out:
# array([[ 0.04411269,  0.02546847,  0.01800893],
#        [-0.05712098, -0.0329788 , -0.02331954],
#        [-0.0390703 , -0.02255725, -0.01595038]])

# %%
latticeconstant = 4.5
atoms = bulk('Si', 'diamond', a=latticeconstant, cubic=True)
atoms.set_calculator(calc)
filt = StrainFilter(atoms)
opt = FIRE(filt)
opt.run(5e-4)
enRef = atoms.get_potential_energy()
volRef = atoms.get_volume()
atoms.get_cell(),enRef, volRef**(1/3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-0a57ebad8d83> in <module>
#       4 filt = StrainFilter(atoms)
#       5 opt = FIRE(filt)
# ----> 6 opt.run(5e-4)
#       7 enRef = atoms.get_potential_energy()
#       8 volRef = atoms.get_volume()
#
# ~/.local/lib/python3.8/site-packages/ase/optimize/optimize.py in run(self, fmax, steps)
#     273         if steps:
#     274             self.max_steps = steps
# --> 275         return Dynamics.run(self)
#     276
#     277     def converged(self, forces=None):
#
# ~/.local/lib/python3.8/site-packages/ase/optimize/optimize.py in run(self)
#     160         *steps*."""
#     161
# --> 162         for converged in Dynamics.irun(self):
#     163             pass
#     164         return converged
#
# ~/.local/lib/python3.8/site-packages/ase/optimize/optimize.py in irun(self)
#     126
#     127         # compute initial structure and log the first step
# --> 128         self.atoms.get_forces()
#     129
#     130         # yield the first time to inspect before logging
#
# ~/.local/lib/python3.8/site-packages/ase/constraints.py in get_forces(self, **kwargs)
#    2203
#    2204     def get_forces(self, **kwargs):
# -> 2205         stress = self.atoms.get_stress(include_ideal_gas=self.include_ideal_gas)
#    2206         return -self.atoms.get_volume() * (stress * self.mask).reshape((2, 3))
#    2207
#
# ~/.local/lib/python3.8/site-packages/ase/atoms.py in get_stress(self, voigt, apply_constraint, include_ideal_gas)
#     824             raise RuntimeError('Atoms object has no calculator.')
#     825
# --> 826         stress = self._calc.get_stress(self)
#     827         shape = stress.shape
#     828
#
# ~/.local/lib/python3.8/site-packages/ase/calculators/calculator.py in get_stress(self, atoms)
#     700
#     701     def get_stress(self, atoms=None):
# --> 702         return self.get_property('stress', atoms)
#     703
#     704     def get_stresses(self, atoms=None):
#
# ~/.local/lib/python3.8/site-packages/ase/calculators/calculator.py in get_property(self, name, atoms, allow_calculation)
#     736             if not allow_calculation:
#     737                 return None
# --> 738             self.calculate(atoms, [name], system_changes)
#     739
#     740         if name == 'magmom' and 'magmom' not in self.results:
#
# ~/postdoc/Castle/notebooks/../castle/calc_ase_interface.py in calculate(self, atoms, properties, system_changes)
#      47             self.results["forces"] = self.model.predict_forces(features)
#      48         if "stress" in properties:
# ---> 49             self.results["stress"] = self.model.predict_stress(features).flatten()
#
# ~/postdoc/Castle/notebooks/../castle/lp_ensamble.py in predict_stress(self, features)
#     113             if len(np.unique(clusters)) == 1:
#     114                 feat = features.get_subset([i])
# --> 115                 s_ = self.potentials[clusters[0]].predict_stress(feat)
#     116             else:
#     117                 alphas = np.array([self.potentials[i].weights
#
# ~/postdoc/Castle/notebooks/../castle/linear_potential.py in predict_stress(self, features)
#      16
#      17     def predict_stress(self, features):
# ---> 18         v = -np.einsum("mcd, d -> mc", features.dX_ds, self.weights)
#      19         return v
#      20
#
# AttributeError: 'GlobalFeatures' object has no attribute 'dX_ds'
